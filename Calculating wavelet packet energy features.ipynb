# %% [markdown]
#                            How wavelet packet energy features is calculated from raw CWRU data set

# %%
#https://github.com/biswajitsahoo1111/cbm_codes_open/blob/master/notebooks/Wavelet_packet_entropy_features_python.ipynb
#Entropy

# %%
import numpy as np
import pandas as pd
import pywt

# %%
df=pd.read_csv("preprocessedfeatures.csv")

# %%
df
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              0 -0.041097 -0.046104 -0.028372  0.001252  0.033796  0.069886
# 1              1  0.048399  0.048399  0.050902  0.050485  0.040889  0.039846
# 2              2  0.186711  0.318764  0.398455  0.410764  0.369875  0.291853
# 3              3 -0.173777 -0.105977 -0.030041  0.042975  0.127047  0.213205
# 4              4 -0.003964 -0.031501 -0.057369 -0.071764 -0.064879 -0.053823
# ...          ...       ...       ...       ...       ...       ...       ...
# 4595        4595 -0.022113  0.033587  0.040889  0.036925  0.028163  0.042558
# 4596        4596  0.046104  0.042975  0.047356  0.064879  0.064254  0.027120
# 4597        4597 -0.105559 -0.078022 -0.015646  0.022530  0.016063 -0.024408
# 4598        4598 -0.002503  0.053614  0.074893  0.087618  0.100970  0.112861
# 4599        4599 -0.046313 -0.055283 -0.038385  0.013143  0.046104  0.041097
#
#              6         7         8  ...      1014      1015      1016  \
# 0     0.117242  0.164389  0.200688  ...  0.005215  0.029623  0.039428
# 1     0.055492  0.069678  0.064879  ...  0.093877 -0.045478 -0.196098
# 2     0.188588  0.079691 -0.045687  ...  0.269948  0.210076  0.138103
# 3     0.274538  0.294148  0.268905  ...  0.125795  0.118076  0.112235
# 4    -0.037968 -0.011057  0.023365  ... -0.009388 -0.011265  0.001669
# ...        ...       ...       ...  ...       ...       ...       ...
# 4595  0.056535  0.061959  0.046313  ...  0.013351  0.024408  0.044435
# 4596 -0.047356 -0.129133 -0.178575  ...  0.020653  0.066340  0.066757
# 4597 -0.057161 -0.044018 -0.023365  ...  0.170439  0.168353  0.129550
# 4598  0.086158  0.035047 -0.025868  ... -0.045270 -0.019610  0.031084
# 4599 -0.000209 -0.025034 -0.017315  ...  0.083655  0.128507  0.108897
#
#           1017      1018      1019      1020      1021      1022      1023
# 0     0.057369  0.087201  0.125169  0.151038  0.136017  0.101387  0.066548
# 1    -0.329195 -0.400750 -0.418900 -0.379263 -0.286012 -0.157087  0.012934
# 2     0.061124 -0.014394 -0.089913 -0.166475 -0.225513 -0.253676 -0.229268
# 3     0.107020  0.088662  0.060498  0.030249  0.014603  0.011891  0.010014
# 4     0.018358  0.025242  0.013351  0.008970  0.014186  0.018150  0.010431
# ...        ...       ...       ...       ...       ...       ...       ...
# 4595  0.054449  0.025451 -0.035465 -0.078648 -0.084281 -0.025660  0.030666
# 4596  0.022948 -0.023782 -0.036925 -0.027329 -0.018984 -0.037968 -0.083655
# 4597  0.109106  0.089705  0.054449 -0.017941 -0.096589 -0.118285 -0.081151
# 4598  0.063836  0.055909  0.030041  0.009805  0.007302  0.006467 -0.021279
# 4599  0.058204 -0.006676 -0.031084 -0.039846 -0.060498 -0.085741 -0.100135
#
# [4600 rows x 1025 columns]

# %%
df.drop(df.columns[[0]], axis = 1, inplace = True)

# %%
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.041097 -0.046104 -0.028372  0.001252  0.033796  0.069886  0.117242
# 1     0.048399  0.048399  0.050902  0.050485  0.040889  0.039846  0.055492
# 2     0.186711  0.318764  0.398455  0.410764  0.369875  0.291853  0.188588
# 3    -0.173777 -0.105977 -0.030041  0.042975  0.127047  0.213205  0.274538
# 4    -0.003964 -0.031501 -0.057369 -0.071764 -0.064879 -0.053823 -0.037968
# ...        ...       ...       ...       ...       ...       ...       ...
# 4595 -0.022113  0.033587  0.040889  0.036925  0.028163  0.042558  0.056535
# 4596  0.046104  0.042975  0.047356  0.064879  0.064254  0.027120 -0.047356
# 4597 -0.105559 -0.078022 -0.015646  0.022530  0.016063 -0.024408 -0.057161
# 4598 -0.002503  0.053614  0.074893  0.087618  0.100970  0.112861  0.086158
# 4599 -0.046313 -0.055283 -0.038385  0.013143  0.046104  0.041097 -0.000209
#
#              7         8         9  ...      1014      1015      1016  \
# 0     0.164389  0.200688  0.215082  ...  0.005215  0.029623  0.039428
# 1     0.069678  0.064879  0.037342  ...  0.093877 -0.045478 -0.196098
# 2     0.079691 -0.045687 -0.149369  ...  0.269948  0.210076  0.138103
# 3     0.294148  0.268905  0.209867  ...  0.125795  0.118076  0.112235
# 4    -0.011057  0.023365  0.070303  ... -0.009388 -0.011265  0.001669
# ...        ...       ...       ...  ...       ...       ...       ...
# 4595  0.061959  0.046313  0.008553  ...  0.013351  0.024408  0.044435
# 4596 -0.129133 -0.178575 -0.149994  ...  0.020653  0.066340  0.066757
# 4597 -0.044018 -0.023365 -0.015229  ...  0.170439  0.168353  0.129550
# 4598  0.035047 -0.025868 -0.067174  ... -0.045270 -0.019610  0.031084
# 4599 -0.025034 -0.017315  0.008553  ...  0.083655  0.128507  0.108897
#
#           1017      1018      1019      1020      1021      1022      1023
# 0     0.057369  0.087201  0.125169  0.151038  0.136017  0.101387  0.066548
# 1    -0.329195 -0.400750 -0.418900 -0.379263 -0.286012 -0.157087  0.012934
# 2     0.061124 -0.014394 -0.089913 -0.166475 -0.225513 -0.253676 -0.229268
# 3     0.107020  0.088662  0.060498  0.030249  0.014603  0.011891  0.010014
# 4     0.018358  0.025242  0.013351  0.008970  0.014186  0.018150  0.010431
# ...        ...       ...       ...       ...       ...       ...       ...
# 4595  0.054449  0.025451 -0.035465 -0.078648 -0.084281 -0.025660  0.030666
# 4596  0.022948 -0.023782 -0.036925 -0.027329 -0.018984 -0.037968 -0.083655
# 4597  0.109106  0.089705  0.054449 -0.017941 -0.096589 -0.118285 -0.081151
# 4598  0.063836  0.055909  0.030041  0.009805  0.007302  0.006467 -0.021279
# 4599  0.058204 -0.006676 -0.031084 -0.039846 -0.060498 -0.085741 -0.100135
#
# [4600 rows x 1024 columns]

# %%
df.shape
# Out:
# (4600, 1024)

# %% [markdown]
# To get a feel of the library, we will apply it to first row of our data frame (df). In the feature matrix,
# we will repeat the calculations for every row of resized_data

# %%
#Converting our data frame to numpy array to implement wavelet transform
b=df.to_numpy()

# %%
b
# Out:
# array([[-0.04109723, -0.046104  , -0.02837169, ...,  0.13601723,
#          0.10138708,  0.06654831],
#        [ 0.04839877,  0.04839877,  0.05090215, ..., -0.28601169,
#         -0.15708738,  0.01293415],
#        [ 0.18671077,  0.31876431,  0.39845538, ..., -0.22551323,
#         -0.25367631, -0.22926831],
#        ...,
#        [-0.10555938, -0.07802215, -0.01564615, ..., -0.09658892,
#         -0.11828492, -0.08115138],
#        [-0.00250338,  0.05361415,  0.07489292, ...,  0.00730154,
#          0.00646708, -0.02127877],
#        [-0.04631262, -0.05528308, -0.03838523, ..., -0.06049846,
#         -0.08574092, -0.10013538]])

# %%
wp = pywt.WaveletPacket(b[0,:], wavelet = "sym8", maxlevel = 3) # Computes 3 level wavelet packet decomposition

# %%
wp

# %%
packet_names = [node.path for node in wp.get_level(3, "natural")]  # Packet node names. 
packet_names  # The naming of nodes as "aaa", "aad" is conventional in wavelets. "a" means approximation. "d" means details.
# Out:
# ['aaa', 'aad', 'ada', 'add', 'daa', 'dad', 'dda', 'ddd']

# %%
[wp[node.path].data.shape for node in wp.get_level(3, "natural")] # Number of coefficients after 3 stage transformation.
# Out:
# [(141,), (141,), (141,), (141,), (141,), (141,), (141,), (141,)]

# %% [markdown]
# Now we will compute the feature matrix for whole dataset. We will use the packet names as extracted above

# %%
feature_matrix_wav_packet_energy = np.repeat(np.nan, 4600*8).reshape(4600,8)
for i in range(len(b)):
    wp = pywt.WaveletPacket(b[i,:], wavelet = "sym8", maxlevel = 3) # Wavelet packet transformation
    for j in range(8):
        new_wp = pywt.WaveletPacket(data = None, wavelet = "sym8", maxlevel = 3)
        new_wp[packet_names[j]] = wp[packet_names[j]].data
        reconstructed_signal = new_wp.reconstruct(update = False) # Signal reconstruction from wavelet packet coefficients
        feature_matrix_wav_packet_energy[i,j] = np.linalg.norm(reconstructed_signal)**2 # Energy of reconstructed signal for every node

# %%
feature_matrix_wav_packet_energy
# Out:
# array([[7.73557600e+00, 7.71835328e+00, 1.23078740e-02, ...,
#         7.08138854e-04, 7.44460935e-04, 2.21766746e-03],
#        [8.69558577e+00, 7.76057737e+00, 1.37063080e-02, ...,
#         1.08812936e-03, 3.89679983e-03, 2.90950362e-03],
#        [1.02493039e+01, 6.91036177e+00, 1.46241941e-02, ...,
#         6.01513916e-04, 2.35589858e-03, 2.90364540e-03],
#        ...,
#        [2.12113048e+00, 2.23488607e+00, 6.13122607e-02, ...,
#         3.32859719e-03, 8.47372317e-03, 1.44268849e-02],
#        [2.02595714e+00, 1.76738811e+00, 6.33498103e-02, ...,
#         4.81611164e-03, 5.90210702e-03, 1.60394187e-02],
#        [1.63143331e+00, 1.75698905e+00, 6.25971771e-02, ...,
#         5.35864103e-03, 5.73349857e-03, 1.58331831e-02]])

# %%
feature_matrix_wav_packet_energy=pd.DataFrame(feature_matrix_wav_packet_energy, columns =['V1', 'V2', 'V3','V4','V5','V6','V7','V8'])

# %%
feature_matrix_wav_packet_energy
# Out:
#              V1         V2        V3        V4        V5        V6        V7  \
# 0      7.735576   7.718353  0.012308  0.085315  0.000040  0.000708  0.000744
# 1      8.695586   7.760577  0.013706  0.146951  0.000066  0.001088  0.003897
# 2     10.249304   6.910362  0.014624  0.124229  0.000061  0.000602  0.002356
# 3     13.546487   5.975831  0.013793  0.086176  0.000056  0.000782  0.000891
# 4     14.398300  11.582615  0.014889  0.091518  0.000059  0.000414  0.001138
# ...         ...        ...       ...       ...       ...       ...       ...
# 4595   2.837118   1.492519  0.066929  0.591914  0.000240  0.004060  0.006650
# 4596   2.177545   1.686253  0.069840  0.561340  0.000285  0.004481  0.006753
# 4597   2.121130   2.234886  0.061312  0.546192  0.000152  0.003329  0.008474
# 4598   2.025957   1.767388  0.063350  0.595987  0.000271  0.004816  0.005902
# 4599   1.631433   1.756989  0.062597  0.570186  0.000261  0.005359  0.005733
#
#             V8
# 0     0.002218
# 1     0.002910
# 2     0.002904
# 3     0.002417
# 4     0.002270
# ...        ...
# 4595  0.015940
# 4596  0.016787
# 4597  0.014427
# 4598  0.016039
# 4599  0.015833
#
# [4600 rows x 8 columns]

# %%
lst = []
for _ in range(1380):
    value = 'B007_1'
    lst.append(value)
for i in range(1380,2760):
    value='IR007_1'
    lst.append(value)
for i in range(2760,4140):
    value='OR007_1'
    lst.append(value)
for i in range(4140,4600):
    value='Normal_1'
    lst.append(value)

# %%
feature_matrix_wav_packet_energy['fault']=lst

# %%
feature_matrix_wav_packet_energy
# Out:
#              V1         V2        V3        V4        V5        V6        V7  \
# 0      7.735576   7.718353  0.012308  0.085315  0.000040  0.000708  0.000744
# 1      8.695586   7.760577  0.013706  0.146951  0.000066  0.001088  0.003897
# 2     10.249304   6.910362  0.014624  0.124229  0.000061  0.000602  0.002356
# 3     13.546487   5.975831  0.013793  0.086176  0.000056  0.000782  0.000891
# 4     14.398300  11.582615  0.014889  0.091518  0.000059  0.000414  0.001138
# ...         ...        ...       ...       ...       ...       ...       ...
# 4595   2.837118   1.492519  0.066929  0.591914  0.000240  0.004060  0.006650
# 4596   2.177545   1.686253  0.069840  0.561340  0.000285  0.004481  0.006753
# 4597   2.121130   2.234886  0.061312  0.546192  0.000152  0.003329  0.008474
# 4598   2.025957   1.767388  0.063350  0.595987  0.000271  0.004816  0.005902
# 4599   1.631433   1.756989  0.062597  0.570186  0.000261  0.005359  0.005733
#
#             V8     fault
# 0     0.002218    B007_1
# 1     0.002910    B007_1
# 2     0.002904    B007_1
# 3     0.002417    B007_1
# 4     0.002270    B007_1
# ...        ...       ...
# 4595  0.015940  Normal_1
# 4596  0.016787  Normal_1
# 4597  0.014427  Normal_1
# 4598  0.016039  Normal_1
# 4599  0.015833  Normal_1
#
# [4600 rows x 9 columns]

# %%
feature_matrix_wav_packet_energy.to_csv("feature_matrix_wav_packet_energy_48k_1024.csv")

# %%
#http://localhost:8888/notebooks/Desktop/CWRU/biswajitsahoo1111-cbm_codes_open-b3cc75a/notebooks/Wavelet_packet_energy_features_python.ipynb
#Energy
